# %%
""" 
financial_dashboard/
├── app.py                    # Main Streamlit app
├── config.py                 # Configuration settings
├── scraper.py               # Web scraping module
├── data_pipeline.py         # Data processing pipeline
├── gdrive_handler.py        # Google Drive integration
├── database_handler.py      # SQLite database operations
├── ml_predictor.py          # Machine learning module
├── email_reporter.py        # Email reporting system
├── dashboard.py             # Dash dashboard (optional alternative)
├── requirements.txt         # Dependencies
├── .env                     # Environment variables
└── utils/
    ├── __init__.py
    ├── helpers.py
    └── visualizations.py 
"""
# Out:
# ' \nfinancial_dashboard/\n├── app.py                    # Main Streamlit app\n├── config.py                 # Configuration settings\n├── scraper.py               # Web scraping module\n├── data_pipeline.py         # Data processing pipeline\n├── gdrive_handler.py        # Google Drive integration\n├── database_handler.py      # SQLite database operations\n├── ml_predictor.py          # Machine learning module\n├── email_reporter.py        # Email reporting system\n├── dashboard.py             # Dash dashboard (optional alternative)\n├── requirements.txt         # Dependencies\n├── .env                     # Environment variables\n└── utils/\n    ├── __init__.py\n    ├── helpers.py\n    └── visualizations.py \n'

# %%
tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tree
#
# NameError: name 'tree' is not defined
