# %%
""" 
streamlit>=1.28.0
pandas>=2.0.0
numpy>=1.24.0
plotly>=5.17.0
dash>=2.14.0
dash-bootstrap-components>=1.5.0
scikit-learn>=1.3.0
sqlite3
requests>=2.31.0
beautifulsoup4>=4.12.0
selenium>=4.15.0
schedule>=1.2.0
google-api-python-client>=2.100.0
google-auth-httplib2>=0.1.0
google-auth-oauthlib>=1.0.0
python-dotenv>=1.0.0
yfinance>=0.2.0
openpyxl>=3.1.0
html5lib>=1.1
lxml>=4.9.0 
"""
# Out:
# ' \nstreamlit>=1.28.0\npandas>=2.0.0\nnumpy>=1.24.0\nplotly>=5.17.0\ndash>=2.14.0\ndash-bootstrap-components>=1.5.0\nscikit-learn>=1.3.0\nsqlite3\nrequests>=2.31.0\nbeautifulsoup4>=4.12.0\nselenium>=4.15.0\nschedule>=1.2.0\ngoogle-api-python-client>=2.100.0\ngoogle-auth-httplib2>=0.1.0\ngoogle-auth-oauthlib>=1.0.0\npython-dotenv>=1.0.0\nyfinance>=0.2.0\nopenpyxl>=3.1.0\nhtml5lib>=1.1\nlxml>=4.9.0 \n'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 import sys
#       4 import os
# ----> 5 sys.path.append(os.path.dirname(os.path.abspath(__file__)))
#       6 from scraper import FinancialScraper
#       7 from datetime import datetime
#
# NameError: name '__file__' is not defined
